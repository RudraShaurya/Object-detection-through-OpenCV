# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.0-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.5 kB ? eta -:--:--
#      ---------------------------------------- 40.5/40.5 kB ? eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (3.5.2)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (4.6.0.66)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (9.2.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (6.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.8.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (2.2.1)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.17.2-cp310-cp310-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (4.64.0)
# Requirement already satisfied: psutil in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (5.9.7)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (1.4.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.34.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->ultralytics) (2022.6.15)
# Requirement already satisfied: filelock in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.12.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (4.10.0)
# Requirement already satisfied: sympy in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (1.10.1)
# Requirement already satisfied: networkx in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.3.1)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.2.2-cp310-cp310-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: colorama in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\tusha\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.2.1)
# Downloading ultralytics-8.2.0-py3-none-any.whl (750 kB)
#    ---------------------------------------- 0.0/750.8 kB ? eta -:--:--
#    ------------------------ -------------- 471.0/750.8 kB 14.4 MB/s eta 0:00:01
#    --------------------------------------- 750.8/750.8 kB 15.8 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading torchvision-0.17.2-cp310-cp310-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------------------------- ------------- 0.8/1.2 MB 51.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 24.6 MB/s eta 0:00:00
# Downloading torch-2.2.2-cp310-cp310-win_amd64.whl (198.6 MB)
#    ---------------------------------------- 0.0/198.6 MB ? eta -:--:--
#    ---------------------------------------- 1.1/198.6 MB 34.4 MB/s eta 0:00:06
#     --------------------------------------- 2.5/198.6 MB 40.5 MB/s eta 0:00:05
#     --------------------------------------- 3.7/198.6 MB 29.2 MB/s eta 0:00:07
#    - -------------------------------------- 5.2/198.6 MB 33.5 MB/s eta 0:00:06
#    - -------------------------------------- 6.5/198.6 MB 32.1 MB/s eta 0:00:06
#    - -------------------------------------- 8.4/198.6 MB 31.8 MB/s eta 0:00:06
#    -- ------------------------------------- 10.2/198.6 MB 32.6 MB/s eta 0:00:06
#    -- ------------------------------------- 11.9/198.6 MB 32.8 MB/s eta 0:00:06
#    -- ------------------------------------- 13.7/198.6 MB 32.8 MB/s eta 0:00:06
#    --- ------------------------------------ 15.3/198.6 MB 34.4 MB/s eta 0:00:06
#    --- ------------------------------------ 16.7/198.6 MB 34.4 MB/s eta 0:00:06
#    --- ------------------------------------ 18.1/198.6 MB 34.4 MB/s eta 0:00:06
#    --- ------------------------------------ 18.9/198.6 MB 32.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 20.3/198.6 MB 31.2 MB/s eta 0:00:06
#    ---- ----------------------------------- 21.9/198.6 MB 29.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 23.5/198.6 MB 29.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 24.9/198.6 MB 31.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 26.5/198.6 MB 28.5 MB/s eta 0:00:07
#    ----- ---------------------------------- 27.8/198.6 MB 28.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 28.1/198.6 MB 28.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 28.3/198.6 MB 25.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 28.9/198.6 MB 23.4 MB/s eta 0:00:08
#    ----- ---------------------------------- 29.4/198.6 MB 23.4 MB/s eta 0:00:08
#    ------ --------------------------------- 30.9/198.6 MB 22.6 MB/s eta 0:00:08
#    ------ --------------------------------- 32.2/198.6 MB 22.6 MB/s eta 0:00:08
#    ------ --------------------------------- 32.5/198.6 MB 22.6 MB/s eta 0:00:08
#    ------ --------------------------------- 34.5/198.6 MB 20.5 MB/s eta 0:00:09
#    ------- -------------------------------- 36.5/198.6 MB 21.1 MB/s eta 0:00:08
#    ------- -------------------------------- 38.2/198.6 MB 22.6 MB/s eta 0:00:08
198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------- ----- 169.1/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------- ----- 170.4/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------- ----- 172.0/198.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------- ---- 173.5/198.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------- ---- 174.8/198.6 MB 32.7 MB/s eta 0:00:01
#    ---------------------------------- ---- 176.4/198.6 MB 34.4 MB/s eta 0:00:01
#    ---------------------------------- ---- 177.7/198.6 MB 34.4 MB/s eta 0:00:01
#    ----------------------------------- --- 179.7/198.6 MB 34.4 MB/s eta 0:00:01
#    ----------------------------------- --- 181.4/198.6 MB 34.4 MB/s eta 0:00:01
#    ----------------------------------- --- 182.9/198.6 MB 32.8 MB/s eta 0:00:01
#    ------------------------------------ -- 184.3/198.6 MB 34.4 MB/s eta 0:00:01
#    ------------------------------------ -- 186.2/198.6 MB 34.4 MB/s eta 0:00:01
#    ------------------------------------ -- 187.9/198.6 MB 34.4 MB/s eta 0:00:01
#    ------------------------------------- - 189.6/198.6 MB 34.4 MB/s eta 0:00:01
#    ------------------------------------- - 191.3/198.6 MB 34.6 MB/s eta 0:00:01
#    ------------------------------------- - 192.8/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  194.3/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  195.9/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  197.4/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------  198.6/198.6 MB 34.4 MB/s eta 0:00:01
#    --------------------------------------- 198.6/198.6 MB 13.1 MB/s eta 0:00:00
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, torch, torchvision, thop, ultralytics
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1
#     Uninstalling torch-2.2.1:
#       Successfully uninstalled torch-2.2.1
# Successfully installed py-cpuinfo-9.0.0 thop-0.1.1.post2209072238 torch-2.2.2 torchvision-0.17.2 ultralytics-8.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.2.1 requires torch==2.2.1, but you have torch 2.2.2 which is incompatible.

# %%
import cv2
import torch
from PIL import Image
from ultralytics import YOLO

# Load the pre-trained YOLOv3 object detection model
model = YOLO("yolov3.pt")

# Set the object class you want to detect (e.g., 'person')
target_class = 'person'

# Initialize the video capture
cap = cv2.VideoCapture(0)  # Use 0 for the default camera, or provide a video file path

while True:
    # Capture a frame from the video
    ret, frame = cap.read()

    # Check if the frame was read successfully
    if not ret:
        print("Failed to read frame from the video. Exiting.")
        break

    # Preprocess the frame for the object detection model
    img = Image.fromarray(frame)
    results = model(img, stream=True)

    # Initialize a list to store the bounding box coordinates
    bounding_boxes = []

    # Parse the output and draw the bounding boxes
    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            class_id = int(box.cls[0])
            if target_class == model.names[class_id]:
                # Draw the bounding box
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)

                # Add the bounding box coordinates to the list
                bounding_boxes.append((x1, y1, x2 - x1, y2 - y1))

    # Display the resulting frame
    cv2.imshow('Object Detection', frame)

    # Press 'q' to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video capture and close all windows
cap.release()
cv2.destroyAllWindows()

# Print the list of bounding box coordinates
print(bounding_boxes)
# Out:
# PRO TIP  Replace 'model=yolov3.pt' with new 'model=yolov3u.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
# 0: 480x640 1 person, 1 chair, 1317.7ms
# Speed: 5.0ms preprocess, 1317.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 1 couch, 1478.1ms
# Speed: 3.4ms preprocess, 1478.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 1 chair, 1284.3ms
# Speed: 3.0ms preprocess, 1284.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 1 chair, 2 toothbrushs, 1287.1ms
# Speed: 1.0ms preprocess, 1287.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 1 chair, 1307.8ms
# Speed: 4.0ms preprocess, 1307.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 1 dog, 1 chair, 1285.5ms
# Speed: 3.0ms preprocess, 1285.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 1 chair, 1317.4ms
# Speed: 3.3ms preprocess, 1317.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 1 chair, 1313.9ms
# Speed: 2.4ms preprocess, 1313.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 1293.6ms
# Speed: 2.0ms preprocess, 1293.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# [(91, 0, 397, 479)]
